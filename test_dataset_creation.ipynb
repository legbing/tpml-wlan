# %%
import numpy as np
import pandas as pd

# %%
import os
import glob

path = "C:\\Users\\spoor\\OneDrive\\Desktop\\TPML-WLAN\\input_node_files_test\\test_"
results = pd.DataFrame()
directories = ["1", "2", "3", "4"]
for i in directories:
    
    for counter, file in enumerate(glob.glob(path+i+"/*.csv")):
        df = pd.read_csv(file, header=None, sep="|")
        results = pd.concat([results, df])

results.to_csv('test.csv', index=None, header=None, sep="|")

# %%
results
# Out:
#                                                     0
# 0   node_code;node_type;wlan_code;x(m);y(m);z(m);c...
# 1   AP_A;0;A;10;10;0;5.0;4;0;0;3;20;-82;99;10000.0...
# 2   STA_A1;1;A;12.437;12.535;0;5.0;4;0;0;3;20;-82;...
# 3   STA_A2;1;A;13.4141;6.2534;0;5.0;4;0;0;3;20;-82...
# 4   STA_A3;1;A;8.6809;8.4456;0;5.0;4;0;0;3;20;-82;...
# ..                                                ...
# 72  STA_J4;1;J;22.4444;46.9925;0;5.0;4;0;0;7;20;-8...
# 73  STA_J5;1;J;32.0104;51.2173;0;5.0;4;0;0;7;20;-8...
# 74  STA_J6;1;J;34.1608;48.5987;0;5.0;4;0;0;7;20;-8...
# 75  STA_J7;1;J;31.8977;54.3313;0;5.0;4;0;0;7;20;-8...
# 76  STA_J8;1;J;29.5763;58.3586;0;5.0;4;0;0;7;20;-8...
#
# [10031 rows x 1 columns]

# %%
input_df = pd.read_csv("test.csv", delimiter=";")

# %%
input_df
# Out:
#       node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0          AP_A         0         A       10       10    0               5.0
# 1        STA_A1         1         A   12.437   12.535    0               5.0
# 2        STA_A2         1         A  13.4141   6.2534    0               5.0
# 3        STA_A3         1         A   8.6809   8.4456    0               5.0
# 4          AP_B         0         B       30       10    0               5.0
# ...         ...       ...       ...      ...      ...  ...               ...
# 10025    STA_J4         1         J  22.4444  46.9925    0               5.0
# 10026    STA_J5         1         J  32.0104  51.2173    0               5.0
# 10027    STA_J6         1         J  34.1608  48.5987    0               5.0
# 10028    STA_J7         1         J  31.8977  54.3313    0               5.0
# 10029    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#       channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                         4               0                   0  ...
# 1                         4               0                   0  ...
# 2                         4               0                   0  ...
# 3                         4               0                   0  ...
# 4                         4               0                   0  ...
# ...                     ...             ...                 ...  ...
# 10025                     4               0                   0  ...
# 10026                     4               0                   0  ...
# 10027                     4               0                   0  ...
# 10028                     4               0                   0  ...
# 10029                     4               0                   0  ...
#
#       traffic_load[pkt/s] packet_length num_packets_aggregated  \
# 0                 10000.0         12000                     64
# 1                 10000.0         12000                     64
# 2                 10000.0         12000                     64
# 3                 10000.0         12000                     64
# 4                 10000.0         12000                     64
# ...                   ...           ...                    ...
# 10025             10000.0         12000                     64
# 10026             10000.0         12000                     64
# 10027             10000.0         12000                     64
# 10028             10000.0         12000                     64
# 10029             10000.0         12000                     64
#
#       capture_effect_model capture_effect_thr constant_per pifs_activated  \
# 0                        0                 10          0.0              0
# 1                        0                 10          0.0              0
# 2                        0                 10          0.0              0
# 3                        0                 10          0.0              0
# 4                        0                 10          0.0              0
# ...                    ...                ...          ...            ...
# 10025                    0                 10          0.0              0
# 10026                    0                 10          0.0              0
# 10027                    0                 10          0.0              0
# 10028                    0                 10          0.0              0
# 10029                    0                 10          0.0              0
#
#       cw_adaptation cont_wind cont_wind_stage
# 0                 0        16               5
# 1                 0        16               5
# 2                 0        16               5
# 3                 0        16               5
# 4                 0        16               5
# ...             ...       ...             ...
# 10025             0        16               5
# 10026             0        16               5
# 10027             0        16               5
# 10028             0        16               5
# 10029             0        16               5
#
# [10030 rows x 24 columns]

# %%
input_df = input_df[input_df.node_code != "node_code"]

# %%
input_df = input_df.reset_index(drop=True)

# %%
# Inserting the columns

# %%
path = "C:\\Users\\spoor\\OneDrive\\Desktop\\TPML-WLAN\\output_simulator_test\\script_output_test_sce"
v = ["1", "2", "3", "4"]

# %%
throughput = []
airtime = []
RSSI = []
interference_map = []
SINR = []

# %%
for i in range(1,5):
    file = path + str(i) + ".txt"
    f = open(file, "r")

    line = f.readlines()
    line = [x.strip() for x in line]
    for count in range(0, 9*50 + 100*(i-1), 7+2*i):
            throughput.append(line[1 + count])
            airtime.append(line[2 + count])
            RSSI.append(line[3 + count])
            interference_map.append(line[4 + count:(4+count)+2*i + 2])
            SINR.append(line[4+ 2*i + 2 + count])

# %%
file = path + "1.txt"
f = open(file, "r")
line = f.readlines()
line = [x.strip() for x in line]
for count in range(0, 9*50, 9):
        throughput.append(line[1 + count])
        airtime.append(line[2 + count])
        RSSI.append(line[3 + count])
        interference_map.append(line[4 + count:4+4+count])
        SINR.append(line[4+4 + count])

# %%
len(throughput)
# Out:
# 200

# %%
SINR[79]
# Out:
# '{Inf,22.70,39.42,24.45,26.67,29.26,22.86,Inf,36.35,25.64,26.65,38.01,26.43,29.77,18.48,35.16,Inf,18.25,13.92,18.66,23.20,20.45,19.50,21.80,20.76,25.61,Inf,38.19,28.88,33.08,23.91,Inf,23.30,28.44,26.24,23.54,Inf,13.49,14.59,19.19,27.27,15.50,17.08,20.26,23.25}'

# %%
len(SINR)
# Out:
# 200

# %%
throughput
# Out:
# ['{257.28,93.39,58.52,105.37,92.62,17.51,2.69,4.45,10.60,10.29,12.67,12.52,10.21,11.67,157.21,31.10,44.08,44.31,37.71,145.69,36.40,39.09,32.18,38.02}',
#  '{214.96,38.94,50.38,43.55,44.62,37.48,63.81,20.18,8.82,18.95,0.00,15.87,179.02,22.73,22.66,23.65,19.66,15.74,17.05,18.66,20.35,18.51,152.99,38.25,45.77,39.71,28.34,0.31,0.61}',
#  '{126.11,9.58,12.93,15.28,12.18,13.29,12.65,12.65,10.86,12.18,14.52,191.16,25.96,22.66,22.96,23.27,24.73,27.42,22.04,22.12,160.62,57.91,48.56,54.14,162.63,28.88,24.76,28.72,25.65,27.88,26.74}',
#  '{52.07,16.67,5.15,5.30,5.68,19.28,118.05,14.30,25.34,24.81,26.80,26.80,69.20,8.91,9.06,23.81,27.42,128.03,14.59,19.20,20.97,10.91,11.60,17.66,12.44,20.66}',
#  '{250.68,83.10,85.79,81.79,71.85,34.02,37.83,20.05,0.14,9.91,0.36,9.64,261.58,75.57,72.19,113.82}',
#  '{Inf,-82.35,-106.97,-119.98,-79.34,-88.83,-108.60,-125.96,-103.96,-108.60;',
#  '-108.60,-94.85,-85.36,-94.85,-106.97,-85.36,Inf,-85.36,-111.61,-94.85;',
#  '{157.67,30.64,6.37,33.02,5.76,28.88,30.87,22.12,108.58,4.58,14.16,18.12,13.36,12.96,14.13,15.67,15.59,85.40,13.21,2.46,15.59,11.75,10.91,15.44,16.05,119.12,16.82,19.43,14.98,18.28,2.92,16.67,7.14,22.89,41.01,0.23,0.38,13.21,4.92,2.69,15.59,1.31,2.69,98.46,32.26,26.27,0.08,32.72,7.14,24.50,2.07,11.21,1.08,0.08,3.00,3.00,3.76,0.23,0.08,121.70,15.05,16.44,13.13,8.10,11.82,10.86,14.75,15.90,15.66,101.61,2.84,17.43,16.28,15.21,14.44,13.90,13.36,8.14,77.26,31.33,42.85,3.07}',
#  '-119.98,-103.96,-79.34,Inf,-122.95,-111.61,-94.85,-79.34,-130.96,-116.81;',
#  '-105.59,-100.95,-105.59,-119.82,-94.85,-85.36,-91.84,-111.61,-85.36,Inf}',
#  '{Inf,-85.36,-100.95,-126.00,-85.36,-94.85,-105.59,-128.97,-106.97,-108.60;',
#  '-105.59,-88.83,-85.36,-94.85,-106.97,-82.35,Inf,-82.35,-105.59,-88.83;',
#  '{115.18,15.66,19.15,21.20,16.21,17.44,10.53,14.98,100.87,22.73,23.58,5.40,21.34,5.16,22.66,55.22,1.84,53.07,0.31,101.38,3.23,15.51,1.77,13.21,16.51,16.67,10.44,5.76,3.69,14.59,19.81,0.00,0.00,0.00,1.69,2.92,5.38,9.83,106.97,32.49,35.77,38.71,22.66,0.54,5.61,6.45,2.46,4.99,0.08,0.00,1.08,1.00,0.46,257.36,90.47,74.73,92.16,146.45,13.47,18.12,16.20,13.41,20.66,16.36,16.48,16.90,14.84,116.21,59.58,56.64}',
#  '-119.98,-103.96,-79.34,Inf,-128.97,-108.60,-94.85,-85.36,-133.97,-119.82;']

# %%
th_out = []
rssi_out = []
sinr_out = []

# %%
for i in range(200):
    th_out = th_out + throughput[i].split(",")
    rssi_out = rssi_out + RSSI[i].split(",")
    sinr_out = sinr_out + SINR[i].split(",")

# %%
output_df = input_df.copy()

# %%
output_df = output_df.assign(RSSI = rssi_out, SINR = sinr_out, throughput=th_out)

# %%
output_df
# Out:
#      node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A       10       10    0               5.0
# 1       STA_A1         1         A   12.437   12.535    0               5.0
# 2       STA_A2         1         A  13.4141   6.2534    0               5.0
# 3       STA_A3         1         A   8.6809   8.4456    0               5.0
# 4         AP_B         0         B       30       10    0               5.0
# ...        ...       ...       ...      ...      ...  ...               ...
# 9826    STA_J4         1         J  22.4444  46.9925    0               5.0
# 9827    STA_J5         1         J  32.0104  51.2173    0               5.0
# 9828    STA_J6         1         J  34.1608  48.5987    0               5.0
# 9829    STA_J7         1         J  31.8977  54.3313    0               5.0
# 9830    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 1                        4               0                   0  ...
# 2                        4               0                   0  ...
# 3                        4               0                   0  ...
# 4                        4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9826                     4               0                   0  ...
# 9827                     4               0                   0  ...
# 9828                     4               0                   0  ...
# 9829                     4               0                   0  ...
# 9830                     4               0                   0  ...
#
#      capture_effect_model capture_effect_thr constant_per pifs_activated  \
# 0                       0                 10          0.0              0
# 1                       0                 10          0.0              0
# 2                       0                 10          0.0              0
# 3                       0                 10          0.0              0
# 4                       0                 10          0.0              0
# ...                   ...                ...          ...            ...
# 9826                    0                 10          0.0              0
# 9827                    0                 10          0.0              0
# 9828                    0                 10          0.0              0
# 9829                    0                 10          0.0              0
# 9830                    0                 10          0.0              0
#
#      cw_adaptation cont_wind cont_wind_stage     RSSI    SINR throughput
# 0                0        16               5     {Inf    {Inf    {257.28
# 1                0        16               5   -54.10   37.39      93.39
# 2                0        16               5   -58.57   32.46      58.52
# 3                0        16               5   -48.09   44.30     105.37
# 4                0        16               5      Inf     Inf      92.62
# ...            ...       ...             ...      ...     ...        ...
# 9826             0        16               5   -68.17   11.06       3.30
# 9827             0        16               5   -52.61   32.17      43.24
# 9828             0        16               5   -59.77   24.86      37.02
# 9829             0        16               5   -60.70   23.68      36.86
# 9830             0        16               5  -68.61}  16.89}     31.41}
#
# [9831 rows x 27 columns]

# %%
import re

# %%
output_df.RSSI = [re.sub(r'[{}]', '', i) for i in output_df.RSSI]
output_df.SINR = [re.sub(r'[{}]', '', i) for i in output_df.SINR]
output_df.throughput = [re.sub(r'[{}]', '', i) for i in output_df.throughput]

# %%
output_df
# Out:
#      node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A       10       10    0               5.0
# 1       STA_A1         1         A   12.437   12.535    0               5.0
# 2       STA_A2         1         A  13.4141   6.2534    0               5.0
# 3       STA_A3         1         A   8.6809   8.4456    0               5.0
# 4         AP_B         0         B       30       10    0               5.0
# ...        ...       ...       ...      ...      ...  ...               ...
# 9826    STA_J4         1         J  22.4444  46.9925    0               5.0
# 9827    STA_J5         1         J  32.0104  51.2173    0               5.0
# 9828    STA_J6         1         J  34.1608  48.5987    0               5.0
# 9829    STA_J7         1         J  31.8977  54.3313    0               5.0
# 9830    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 1                        4               0                   0  ...
# 2                        4               0                   0  ...
# 3                        4               0                   0  ...
# 4                        4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9826                     4               0                   0  ...
# 9827                     4               0                   0  ...
# 9828                     4               0                   0  ...
# 9829                     4               0                   0  ...
# 9830                     4               0                   0  ...
#
#      capture_effect_model capture_effect_thr constant_per pifs_activated  \
# 0                       0                 10          0.0              0
# 1                       0                 10          0.0              0
# 2                       0                 10          0.0              0
# 3                       0                 10          0.0              0
# 4                       0                 10          0.0              0
# ...                   ...                ...          ...            ...
# 9826                    0                 10          0.0              0
# 9827                    0                 10          0.0              0
# 9828                    0                 10          0.0              0
# 9829                    0                 10          0.0              0
# 9830                    0                 10          0.0              0
#
#      cw_adaptation cont_wind cont_wind_stage    RSSI   SINR throughput
# 0                0        16               5     Inf    Inf     257.28
# 1                0        16               5  -54.10  37.39      93.39
# 2                0        16               5  -58.57  32.46      58.52
# 3                0        16               5  -48.09  44.30     105.37
# 4                0        16               5     Inf    Inf      92.62
# ...            ...       ...             ...     ...    ...        ...
# 9826             0        16               5  -68.17  11.06       3.30
# 9827             0        16               5  -52.61  32.17      43.24
# 9828             0        16               5  -59.77  24.86      37.02
# 9829             0        16               5  -60.70  23.68      36.86
# 9830             0        16               5  -68.61  16.89      31.41
#
# [9831 rows x 27 columns]

# %%
air_out = []
int_out = []

# %%
for i in range(200):
    air_out = air_out + airtime[i].split(";")

# %%
air_out = [x.split(",") for x in air_out if x != "{" and x != "}"]

# %%
len(air_out)
# Out:
# 1400

# %%
output_df2 = output_df.copy()
output_df2 = output_df2.assign(airtime=np.nan)
output_df2
# Out:
#      node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A       10       10    0               5.0
# 1       STA_A1         1         A   12.437   12.535    0               5.0
# 2       STA_A2         1         A  13.4141   6.2534    0               5.0
# 3       STA_A3         1         A   8.6809   8.4456    0               5.0
# 4         AP_B         0         B       30       10    0               5.0
# ...        ...       ...       ...      ...      ...  ...               ...
# 9826    STA_J4         1         J  22.4444  46.9925    0               5.0
# 9827    STA_J5         1         J  32.0104  51.2173    0               5.0
# 9828    STA_J6         1         J  34.1608  48.5987    0               5.0
# 9829    STA_J7         1         J  31.8977  54.3313    0               5.0
# 9830    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 1                        4               0                   0  ...
# 2                        4               0                   0  ...
# 3                        4               0                   0  ...
# 4                        4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9826                     4               0                   0  ...
# 9827                     4               0                   0  ...
# 9828                     4               0                   0  ...
# 9829                     4               0                   0  ...
# 9830                     4               0                   0  ...
#
#      capture_effect_thr constant_per pifs_activated cw_adaptation cont_wind  \
# 0                    10          0.0              0             0        16
# 1                    10          0.0              0             0        16
# 2                    10          0.0              0             0        16
# 3                    10          0.0              0             0        16
# 4                    10          0.0              0             0        16
# ...                 ...          ...            ...           ...       ...
# 9826                 10          0.0              0             0        16
# 9827                 10          0.0              0             0        16
# 9828                 10          0.0              0             0        16
# 9829                 10          0.0              0             0        16
# 9830                 10          0.0              0             0        16
#
#      cont_wind_stage    RSSI   SINR throughput airtime
# 0                  5     Inf    Inf     257.28     NaN
# 1                  5  -54.10  37.39      93.39     NaN
# 2                  5  -58.57  32.46      58.52     NaN
# 3                  5  -48.09  44.30     105.37     NaN
# 4                  5     Inf    Inf      92.62     NaN
# ...              ...     ...    ...        ...     ...
# 9826               5  -68.17  11.06       3.30     NaN
# 9827               5  -52.61  32.17      43.24     NaN
# 9828               5  -59.77  24.86      37.02     NaN
# 9829               5  -60.70  23.68      36.86     NaN
# 9830               5  -68.61  16.89      31.41     NaN
#
# [9831 rows x 28 columns]

# %%
out3 = output_df2[output_df2['node_type'].isin(['0'])]

# %%
out3["airtime"] = [air_out[i] for i in range(len(air_out))]
# Out:
# C:\Users\spoor\AppData\Local\Temp/ipykernel_11900/2435973147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out3["airtime"] = [air_out[i] for i in range(len(air_out))]

# %%
out3
# Out:
#      node_code node_type wlan_code x(m) y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A   10   10    0               5.0
# 4         AP_B         0         B   30   10    0               5.0
# 14        AP_C         0         C   50   10    0               5.0
# 19        AP_D         0         D   70   10    0               5.0
# 24        AP_A         0         A   10   10    0               5.0
# ...        ...       ...       ...  ...  ...  ...               ...
# 9800      AP_F         0         F   30   30    0               5.0
# 9807      AP_G         0         G   50   30    0               5.0
# 9810      AP_H         0         H   70   30    0               5.0
# 9817      AP_I         0         I   10   50    0               5.0
# 9822      AP_J         0         J   30   50    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 4                        4               0                   0  ...
# 14                       4               0                   0  ...
# 19                       4               0                   0  ...
# 24                       4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9800                     4               0                   0  ...
# 9807                     4               0                   0  ...
# 9810                     4               0                   0  ...
# 9817                     4               4                   4  ...
# 9822                     4               0                   0  ...
#
#      capture_effect_thr constant_per pifs_activated cw_adaptation cont_wind  \
# 0                    10          0.0              0             0        16
# 4                    10          0.0              0             0        16
# 14                   10          0.0              0             0        16
# 19                   10          0.0              0             0        16
# 24                   10          0.0              0             0        16
# ...                 ...          ...            ...           ...       ...
# 9800                 10          0.0              0             0        16
# 9807                 10          0.0              0             0        16
# 9810                 10          0.0              0             0        16
# 9817                 10          0.0              0             0        16
# 9822                 10          0.0              0             0        16
#
#      cont_wind_stage RSSI SINR throughput  \
# 0                  5  Inf  Inf     257.28
# 4                  5  Inf  Inf      92.62
# 14                 5  Inf  Inf     157.21
# 19                 5  Inf  Inf     145.69
# 24                 5  Inf  Inf     214.96
# ...              ...  ...  ...        ...
# 9800               5  Inf  Inf      46.16
# 9807               5  Inf  Inf     116.58
# 9810               5  Inf  Inf      84.17
# 9817               5  Inf  Inf      20.81
# 9822               5  Inf  Inf     195.46
#
#                                                 airtime
# 0                         [{75.48, 68.49, 68.49, 68.49]
# 4     [41.34, 37.29, 37.29, 37.29, 37.29, 37.29, 37....
# 14                         [63.40, 61.25, 61.25, 61.25]
# 19                         [89.38, 62.19, 62.19, 62.19]
# 24    [{90.22, 90.22, 90.22, 90.22, 66.31, 66.31, 66...
# ...                                                 ...
# 9800  [42.97, 18.74, 18.69, 18.69, 15.41, 15.41, 15....
# 9807  [35.89, 35.16, 35.16, 35.16, 35.16, 35.16, 35....
# 9810                       [57.75, 40.43, 40.43, 40.43]
# 9817                                     [82.95, 31.52]
# 9822  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
#
# [1400 rows x 28 columns]

# %%
output_df2.loc[out3.index, :] = out3[:]

# %%
output_df2.head(20)
# Out:
#    node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0       AP_A         0         A       10       10    0               5.0
# 1     STA_A1         1         A   12.437   12.535    0               5.0
# 2     STA_A2         1         A  13.4141   6.2534    0               5.0
# 3     STA_A3         1         A   8.6809   8.4456    0               5.0
# 4       AP_B         0         B       30       10    0               5.0
# 5     STA_B1         1         B  30.1661   4.7778    0               5.0
# 6     STA_B2         1         B  30.4521  19.9496    0               5.0
# 7     STA_B3         1         B  25.2142   1.4885    0               5.0
# 8     STA_B4         1         B  36.2233  17.1764    0               5.0
# 9     STA_B5         1         B  36.1391   9.3586    0               5.0
# 10    STA_B6         1         B  34.1068  14.6258    0               5.0
# 11    STA_B7         1         B  37.4773   9.6729    0               5.0
# 12    STA_B8         1         B  37.1393   7.7462    0               5.0
# 13    STA_B9         1         B  25.6159   6.4672    0               5.0
# 14      AP_C         0         C       50       10    0               5.0
# 15    STA_C1         1         C  51.5053   3.4918    0               5.0
# 16    STA_C2         1         C  50.5999  16.9466    0               5.0
# 17    STA_C3         1         C  47.8692  13.0659    0               5.0
# 18    STA_C4         1         C  46.4785  14.4772    0               5.0
# 19      AP_D         0         D       70       10    0               5.0
#
#    channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                      4               0                   0  ...
# 1                      4               0                   0  ...
# 2                      4               0                   0  ...
# 3                      4               0                   0  ...
# 4                      4               0                   0  ...
# 5                      4               0                   0  ...
# 6                      4               0                   0  ...
# 7                      4               0                   0  ...
# 8                      4               0                   0  ...
# 9                      4               0                   0  ...
# 10                     4               0                   0  ...
# 11                     4               0                   0  ...
# 12                     4               0                   0  ...
# 13                     4               0                   0  ...
# 14                     4               0                   0  ...
# 15                     4               0                   0  ...
# 16                     4               0                   0  ...
# 17                     4               0                   0  ...
# 18                     4               0                   0  ...
# 19                     4               0                   0  ...
#
#    capture_effect_thr constant_per pifs_activated cw_adaptation cont_wind  \
# 0                  10          0.0              0             0        16
# 1                  10          0.0              0             0        16
# 2                  10          0.0              0             0        16
# 3                  10          0.0              0             0        16
# 4                  10          0.0              0             0        16
# 5                  10          0.0              0             0        16
# 6                  10          0.0              0             0        16
# 7                  10          0.0              0             0        16
# 8                  10          0.0              0             0        16
# 9                  10          0.0              0             0        16
# 10                 10          0.0              0             0        16
# 11                 10          0.0              0             0        16
# 12                 10          0.0              0             0        16
# 13                 10          0.0              0             0        16
# 14                 10          0.0              0             0        16
# 15                 10          0.0              0             0        16
# 16                 10          0.0              0             0        16
# 17                 10          0.0              0             0        16
# 18                 10          0.0              0             0        16
# 19                 10          0.0              0             0        16
#
#    cont_wind_stage    RSSI   SINR throughput  \
# 0                5     Inf    Inf     257.28
# 1                5  -54.10  37.39      93.39
# 2                5  -58.57  32.46      58.52
# 3                5  -48.09  44.30     105.37
# 4                5     Inf    Inf      92.62
# 5                5  -61.97  20.86      17.51
# 6                5  -71.39  12.76       2.69
# 7                5  -71.07  18.46       4.45
# 8                5  -70.61  17.55      10.60
# 9                5  -64.19  22.56      10.29
# 10               5  -64.22  21.98      12.67
# 11               5  -66.93  21.02      12.52
# 12               5  -66.93  20.88      10.21
# 13               5  -62.95  20.84      11.67
# 14               5     Inf    Inf     157.21
# 15               5  -62.28  21.67      31.10
# 16               5  -62.89  21.41      44.08
# 17               5  -54.81  30.10      44.31
# 18               5  -60.10  25.38      37.71
# 19               5     Inf    Inf     145.69
#
#                                               airtime
# 0                       [{75.48, 68.49, 68.49, 68.49]
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [41.34, 37.29, 37.29, 37.29, 37.29, 37.29, 37....
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                       [63.40, 61.25, 61.25, 61.25]
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                       [89.38, 62.19, 62.19, 62.19]
#
# [20 rows x 28 columns]

# %%
output_df2.airtime = pd.Series(output_df2.airtime).fillna(method='ffill')

# %%
from itertools import chain

int_out = list(chain.from_iterable(interference_map))


output_df2 = output_df2.assign(interference_map=np.nan)
out3 = output_df2[output_df2['node_type'].isin(['0'])]
out3["interference_map"] = [int_out[i] for i in range(len(int_out))]
output_df2.loc[out3.index, :] = out3[:]
# Out:
# C:\Users\spoor\AppData\Local\Temp/ipykernel_11900/606108541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out3["interference_map"] = [int_out[i] for i in range(len(int_out))]

# %%
output_df2
# Out:
#      node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A       10       10    0               5.0
# 1       STA_A1         1         A   12.437   12.535    0               5.0
# 2       STA_A2         1         A  13.4141   6.2534    0               5.0
# 3       STA_A3         1         A   8.6809   8.4456    0               5.0
# 4         AP_B         0         B       30       10    0               5.0
# ...        ...       ...       ...      ...      ...  ...               ...
# 9826    STA_J4         1         J  22.4444  46.9925    0               5.0
# 9827    STA_J5         1         J  32.0104  51.2173    0               5.0
# 9828    STA_J6         1         J  34.1608  48.5987    0               5.0
# 9829    STA_J7         1         J  31.8977  54.3313    0               5.0
# 9830    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 1                        4               0                   0  ...
# 2                        4               0                   0  ...
# 3                        4               0                   0  ...
# 4                        4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9826                     4               0                   0  ...
# 9827                     4               0                   0  ...
# 9828                     4               0                   0  ...
# 9829                     4               0                   0  ...
# 9830                     4               0                   0  ...
#
#      constant_per pifs_activated cw_adaptation cont_wind cont_wind_stage  \
# 0             0.0              0             0        16               5
# 1             0.0              0             0        16               5
# 2             0.0              0             0        16               5
# 3             0.0              0             0        16               5
# 4             0.0              0             0        16               5
# ...           ...            ...           ...       ...             ...
# 9826          0.0              0             0        16               5
# 9827          0.0              0             0        16               5
# 9828          0.0              0             0        16               5
# 9829          0.0              0             0        16               5
# 9830          0.0              0             0        16               5
#
#         RSSI   SINR throughput  \
# 0        Inf    Inf     257.28
# 1     -54.10  37.39      93.39
# 2     -58.57  32.46      58.52
# 3     -48.09  44.30     105.37
# 4        Inf    Inf      92.62
# ...      ...    ...        ...
# 9826  -68.17  11.06       3.30
# 9827  -52.61  32.17      43.24
# 9828  -59.77  24.86      37.02
# 9829  -60.70  23.68      36.86
# 9830  -68.61  16.89      31.41
#
#                                                 airtime  \
# 0                         [{75.48, 68.49, 68.49, 68.49]
# 1                         [{75.48, 68.49, 68.49, 68.49]
# 2                         [{75.48, 68.49, 68.49, 68.49]
# 3                         [{75.48, 68.49, 68.49, 68.49]
# 4     [41.34, 37.29, 37.29, 37.29, 37.29, 37.29, 37....
# ...                                                 ...
# 9826  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9827  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9828  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9829  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9830  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
#
#                   interference_map
# 0     {Inf,-85.36,-103.96,-122.99;
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4       -82.35,Inf,-82.35,-103.96;
# ...                            ...
# 9826                           NaN
# 9827                           NaN
# 9828                           NaN
# 9829                           NaN
# 9830                           NaN
#
# [9831 rows x 29 columns]

# %%
output_df2.interference_map = [str(output_df2.interference_map[i]) for i in range(len(output_df2)) if output_df2.interference_map[i] != np.nan]

# %%
output_df2.airtime = [[re.sub(r'[{}]', '', x) for x in i] for i in output_df2.airtime]
output_df2.interference_map = [re.sub(r'[{};]', '', i) for i in output_df2.interference_map if i != np.nan]

# %%
output_df2
# Out:
#      node_code node_type wlan_code     x(m)     y(m) z(m) central_freq(GHz)  \
# 0         AP_A         0         A       10       10    0               5.0
# 1       STA_A1         1         A   12.437   12.535    0               5.0
# 2       STA_A2         1         A  13.4141   6.2534    0               5.0
# 3       STA_A3         1         A   8.6809   8.4456    0               5.0
# 4         AP_B         0         B       30       10    0               5.0
# ...        ...       ...       ...      ...      ...  ...               ...
# 9826    STA_J4         1         J  22.4444  46.9925    0               5.0
# 9827    STA_J5         1         J  32.0104  51.2173    0               5.0
# 9828    STA_J6         1         J  34.1608  48.5987    0               5.0
# 9829    STA_J7         1         J  31.8977  54.3313    0               5.0
# 9830    STA_J8         1         J  29.5763  58.3586    0               5.0
#
#      channel_bonding_model primary_channel min_channel_allowed  ...  \
# 0                        4               0                   0  ...
# 1                        4               0                   0  ...
# 2                        4               0                   0  ...
# 3                        4               0                   0  ...
# 4                        4               0                   0  ...
# ...                    ...             ...                 ...  ...
# 9826                     4               0                   0  ...
# 9827                     4               0                   0  ...
# 9828                     4               0                   0  ...
# 9829                     4               0                   0  ...
# 9830                     4               0                   0  ...
#
#      constant_per pifs_activated cw_adaptation cont_wind cont_wind_stage  \
# 0             0.0              0             0        16               5
# 1             0.0              0             0        16               5
# 2             0.0              0             0        16               5
# 3             0.0              0             0        16               5
# 4             0.0              0             0        16               5
# ...           ...            ...           ...       ...             ...
# 9826          0.0              0             0        16               5
# 9827          0.0              0             0        16               5
# 9828          0.0              0             0        16               5
# 9829          0.0              0             0        16               5
# 9830          0.0              0             0        16               5
#
#         RSSI   SINR throughput  \
# 0        Inf    Inf     257.28
# 1     -54.10  37.39      93.39
# 2     -58.57  32.46      58.52
# 3     -48.09  44.30     105.37
# 4        Inf    Inf      92.62
# ...      ...    ...        ...
# 9826  -68.17  11.06       3.30
# 9827  -52.61  32.17      43.24
# 9828  -59.77  24.86      37.02
# 9829  -60.70  23.68      36.86
# 9830  -68.61  16.89      31.41
#
#                                                 airtime  \
# 0                          [75.48, 68.49, 68.49, 68.49]
# 1                          [75.48, 68.49, 68.49, 68.49]
# 2                          [75.48, 68.49, 68.49, 68.49]
# 3                          [75.48, 68.49, 68.49, 68.49]
# 4     [41.34, 37.29, 37.29, 37.29, 37.29, 37.29, 37....
# ...                                                 ...
# 9826  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9827  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9828  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9829  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
# 9830  [81.21, 79.61, 79.61, 79.61, 78.43, 78.43, 78....
#
#                 interference_map
# 0     Inf,-85.36,-103.96,-122.99
# 1                            nan
# 2                            nan
# 3                            nan
# 4      -82.35,Inf,-82.35,-103.96
# ...                          ...
# 9826                         nan
# 9827                         nan
# 9828                         nan
# 9829                         nan
# 9830                         nan
#
# [9831 rows x 29 columns]

# %%
output_df2.interference_map = output_df2.interference_map.replace('nan', np.nan)

# %%
output_df2.airtime = [[float(output_df2.airtime[i][j]) for j in range(len(output_df2.airtime[i]))] for i in range(len(output_df2))]

# %%
output_df2.to_csv("test_dataset.csv")
